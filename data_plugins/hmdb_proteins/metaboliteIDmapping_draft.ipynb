# %% [markdown]
# # Testing package `bioconductor-metaboliteIDmapping`

# %%
import rpy2.robjects as robjects
import pandas as pd
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

from rpy2.robjects.conversion import localconverter
#robjects.r('install.packages("BiocManager", '
 #          'repos="http://cran.r-project.org")')

# %%
#robjects.r('BiocManager::install("metaboliteIDmapping")')
# Out:
# R[write to console]: Bioconductor version 3.13 (BiocManager 1.30.16), R 4.1.1 (2021-08-10)
#
# R[write to console]: Old packages: 'AnnotationDbi', 'AnnotationHub', 'BiocSklearn', 'Biostrings',
#   'GenomeInfoDb', 'MatrixGenerics', 'RSQLite', 'later', 'shiny', 'xfun'
# Update all/some/none? [a/s/n]: Update all/some/none? [a/s/n]:
# R[write to console]: also installing the dependency ‘fontawesome’
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/fontawesome_0.2.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1117463 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.1 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/AnnotationDbi_1.54.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 4328287 bytes (4.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 4.1 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/AnnotationHub_3.0.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1323251 bytes (1.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 1.3 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/BiocSklearn_1.14.1.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 34099282 bytes (32.5 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 32.5 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/Biostrings_2.60.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 12645733 bytes (12.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 12.1 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/GenomeInfoDb_1.28.4.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3457430 bytes (3.3 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.3 MB
#
#
# R[write to console]: trying URL 'https://bioconductor.org/packages/3.13/bioc/src/contrib/MatrixGenerics_1.4.3.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 28253 bytes (27 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 27 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/RSQLite_2.2.8.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3628717 bytes (3.5 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 3.5 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/later_1.3.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 63785 bytes (62 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 62 KB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/shiny_1.7.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 2962297 bytes (2.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 2.8 MB
#
#
# R[write to console]: trying URL 'https://cloud.r-project.org/src/contrib/xfun_0.26.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 113158 bytes (110 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 110 KB
#
#
# * installing *source* package ‘fontawesome’ ...
# ** package ‘fontawesome’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (fontawesome)
# * installing *source* package ‘BiocSklearn’ ...
# ** using non-staged installation via StagedInstall field
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded
# * DONE (BiocSklearn)
# * installing *source* package ‘GenomeInfoDb’ ...
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (GenomeInfoDb)
# * installing *source* package ‘MatrixGenerics’ ...
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (MatrixGenerics)
# * installing *source* package ‘RSQLite’ ...
# ** package ‘RSQLite’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** libs
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbColumn.cpp -o DbColumn.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbColumnDataSource.cpp -o DbColumnDataSource.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbColumnDataSourceFactory.cpp -o DbColumnDataSourceFactory.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbColumnStorage.cpp -o DbColumnStorage.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbConnection.cpp -o DbConnection.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbDataFrame.cpp -o DbDataFrame.o
# In file included from DbDataFrame.cpp:7:
# vendor/boost/bind.hpp:36:1: warning: The practice of declaring the Bind placeholders (_1, _2, ...) in the global namespace is deprecated. Please use <boost/bind/bind.hpp> + using namespace boost::placeholders, or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior. [-W#pragma-messages]
# BOOST_PRAGMA_MESSAGE(
# ^
# vendor/boost/config/pragma_message.hpp:24:34: note: expanded from macro 'BOOST_PRAGMA_MESSAGE'
# # define BOOST_PRAGMA_MESSAGE(x) _Pragma(BOOST_STRINGIZE(message(x)))
#                                  ^
# <scratch space>:2:2: note: expanded from here
#  message("The practice of declaring the Bind placeholders (_1, _2, ...) " "in the global namespace is deprecated. Please use " "<boost/bind/bind.hpp> + using namespace boost::placeholders, " "or define BOOST_BIND_GLOBAL_PLACEHOLDERS to retain the current behavior.")
#  ^
# 1 warning generated.
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c DbResult.cpp -o DbResult.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c RcppExports.cpp -o RcppExports.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c SqliteColumnDataSource.cpp -o SqliteColumnDataSource.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c SqliteColumnDataSourceFactory.cpp -o SqliteColumnDataSourceFactory.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c SqliteDataFrame.cpp -o SqliteDataFrame.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c SqliteResult.cpp -o SqliteResult.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c SqliteResultImpl.cpp -o SqliteResultImpl.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c affinity.c -o affinity.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c connection.cpp -o connection.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c extension-functions.c -o extension-functions.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c extensions.cpp -o extensions.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c import-file.c -o import-file.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c regexp.c -o regexp.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c result.cpp -o result.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c rsqlite.cpp -o rsqlite.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -I. -Ivendor -DRSQLITE_USE_BUNDLED_SQLITE -DSQLITE_ENABLE_RTREE -DSQLITE_ENABLE_FTS3 -DSQLITE_ENABLE_FTS3_PARENTHESIS -DSQLITE_ENABLE_FTS5 -DSQLITE_ENABLE_JSON1 -DSQLITE_ENABLE_STAT4 -DSQLITE_SOUNDEX -DRCPP_DEFAULT_INCLUDE_CALL=false -DRCPP_USING_UTF8_ERROR_STRING -DBOOST_NO_AUTO_PTR -DSQLITE_MAX_LENGTH=2147483647 -DHAVE_USLEEP=1 -I'/opt/anaconda3/envs/su_lab/lib/R/library/plogr/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c vendor/sqlite3/sqlite3.c -o vendor/sqlite3/sqlite3.o
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++14 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/opt/anaconda3/envs/su_lab/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/opt/anaconda3/envs/su_lab/lib -L/opt/anaconda3/envs/su_lab/lib -o RSQLite.dylib DbColumn.o DbColumnDataSource.o DbColumnDataSourceFactory.o DbColumnStorage.o DbConnection.o DbDataFrame.o DbResult.o RcppExports.o SqliteColumnDataSource.o SqliteColumnDataSourceFactory.o SqliteDataFrame.o SqliteResult.o SqliteResultImpl.o affinity.o connection.o extension-functions.o extensions.o import-file.o regexp.o result.o rsqlite.o vendor/sqlite3/sqlite3.o -L/opt/anaconda3/envs/su_lab/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# ld: unsupported tapi file type '!tapi-tbd' in YAML file '/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/System/Library/Frameworks//CoreFoundation.framework/CoreFoundation.tbd' for architecture x86_64
# clang-12: error: linker command failed with exit code 1 (use -v to see invocation)
# make: *** [/opt/anaconda3/envs/su_lab/lib/R/share/make/shlib.mk:10: RSQLite.dylib] Error 1
# ERROR: compilation failed for package ‘RSQLite’
# * removing ‘/opt/anaconda3/envs/su_lab/lib/R/library/RSQLite’
# * restoring previous ‘/opt/anaconda3/envs/su_lab/lib/R/library/RSQLite’
# * installing *source* package ‘later’ ...
# ** package ‘later’ successfully unpacked and MD5 sums checked
# ** using staged installation
# Running configure script
# -latomic linker flag needed.
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -pthread -DSTRICT_R_HEADERS  -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c RcppExports.cpp -o RcppExports.o
# ** libs
# x86_64-apple-darwin13.4.0-clang++ -std=gnu++11 -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG -pthread -DSTRICT_R_HEADERS  -I'/opt/anaconda3/envs/su_lab/lib/R/library/Rcpp/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden  -fmessage-length=0 -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c callback_registry.cpp -o callback_registry.o
# In file included from callback_registry.cpp:6:
# In file included from ./callback_registry.h:10:
# ./threadutils.h:129:9: warning: 'timespec_get' is only available on macOS 10.15 or newer [-Wunguarded-availability-new]
#     if (timespec_get(&ts, TIME_UTC) != TIME_UTC) {
#         ^~~~~~~~~~~~
# /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/time.h:199:5: note: 'timespec_get' has been marked as being introduced in macOS 10.15 here, but the deployment target is macOS 10.9.0
# int timespec_get(struct timespec *ts, int base);
#     ^
# ./threadutils.h:129:9: note: enclose 'timespec_get' in a __builtin_available check to silence this warning
#     if (timespec_get(&ts, TIME_UTC) != TIME_UTC) {
#         ^~~~~~~~~~~~
# 1 warning generated.
# ...
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c match_pdict.c -o match_pdict.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c match_pdict_ACtree2.c -o match_pdict_ACtree2.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c match_pdict_Twobit.c -o match_pdict_Twobit.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c match_pdict_utils.c -o match_pdict_utils.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c match_reporting.c -o match_reporting.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c matchprobes.c -o matchprobes.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c pmatchPattern.c -o pmatchPattern.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c read_fasta_files.c -o read_fasta_files.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c read_fastq_files.c -o read_fastq_files.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c replaceAt.c -o replaceAt.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c replace_letter_at.c -o replace_letter_at.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c strutils.c -o strutils.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c translate.c -o translate.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c unstrsplit_methods.c -o unstrsplit_methods.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c utils.c -o utils.o
# x86_64-apple-darwin13.4.0-clang -I"/opt/anaconda3/envs/su_lab/lib/R/include" -DNDEBUG  -I'/opt/anaconda3/envs/su_lab/lib/R/library/S4Vectors/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/IRanges/include' -I'/opt/anaconda3/envs/su_lab/lib/R/library/XVector/include' -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/su_lab/include -mmacosx-version-min=10.9 -I/opt/anaconda3/envs/su_lab/include   -fPIC  -march=core2 -mtune=haswell -mssse3 -ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/su_lab/include -fdebug-prefix-map=/Users/runner/miniforge3/conda-bld/r-base-split_1628613019450/work=/usr/local/src/conda/r-base-4.1.1 -fdebug-prefix-map=/opt/anaconda3/envs/su_lab=/usr/local/src/conda-prefix  -c xscat.c -o xscat.o
# x86_64-apple-darwin13.4.0-clang -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -single_module -multiply_defined suppress -L/opt/anaconda3/envs/su_lab/lib/R/lib -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/opt/anaconda3/envs/su_lab/lib -L/opt/anaconda3/envs/su_lab/lib -o Biostrings.dylib BAB_class.o BitMatrix.o IRanges_stubs.o MIndex_class.o PreprocessedTB_class.o R_init_Biostrings.o RoSeqs_utils.o S4Vectors_stubs.o SparseList_utils.o XStringSetList_class.o XStringSet_class.o XString_class.o XVector_stubs.o align_needwunsQS.o align_pairwiseAlignment.o align_utils.o find_palindromes.o gtestsim.o inject_code.o letter_frequency.o lowlevel_matching.o match_PWM.o match_pattern.o match_pattern_boyermoore.o match_pattern_indels.o match_pattern_shiftor.o match_pdict.o match_pdict_ACtree2.o match_pdict_Twobit.o match_pdict_utils.o match_reporting.o matchprobes.o pmatchPattern.o read_fasta_files.o read_fastq_files.o replaceAt.o replace_letter_at.o strutils.o translate.o unstrsplit_methods.o utils.o xscat.o -L/opt/anaconda3/envs/su_lab/lib/R/lib -lR -Wl,-framework -Wl,CoreFoundation
# ld: warning: -pie being ignored. It is only used when linking a main executable
# ld: unsupported tapi file type '!tapi-tbd' in YAML file '/Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/lib/libSystem.tbd' for architecture x86_64
# clang-12: error: linker command failed with exit code 1 (use -v to see invocation)
# make: *** [/opt/anaconda3/envs/su_lab/lib/R/share/make/shlib.mk:10: Biostrings.dylib] Error 1
# ERROR: compilation failed for package ‘Biostrings’
# * removing ‘/opt/anaconda3/envs/su_lab/lib/R/library/Biostrings’
# * restoring previous ‘/opt/anaconda3/envs/su_lab/lib/R/library/Biostrings’
# * installing *source* package ‘shiny’ ...
# ** package ‘shiny’ successfully unpacked and MD5 sums checked
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# *** copying figures
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (shiny)
# * installing *source* package ‘AnnotationHub’ ...
# ** using staged installation
# ** R
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (AnnotationHub)
# R[write to console]:
#
# R[write to console]:
# R[write to console]: The downloaded source packages are in
# 	‘/private/var/folders/2t/n_m95zxn1s5fjlvz718g6s4m0000gp/T/RtmpZjtIDF/downloaded_packages’
# R[write to console]:
# R[write to console]:
#
# R[write to console]: Updating HTML index of packages in '.Library'
#
# R[write to console]: Making 'packages.html' ...
# R[write to console]:  done
# <rpy2.robjects.vectors.StrVector object at 0x7f8908ab0a40> [RTYPES.STRSXP]
# R classes: ('character',)
# ['metaboliteIDmapping']

# %%
robjects.r('library(metaboliteIDmapping)')
# Out:
# <rpy2.robjects.vectors.StrVector object at 0x7f88f9dd8d80> [RTYPES.STRSXP]
# R classes: ('character',)
# ['metaboli..., 'tools', 'stats', 'graphics', ..., 'utils', 'datasets', 'methods', 'base']

# %%
metaMap=importr("metaboliteIDmapping")

# %%
type(metaMap)
# Out:
# rpy2.robjects.packages.InstalledSTPackage

# %%
type(metaMap.metabolitesMapping)
# Out:
# rpy2.robjects.vectors.DataFrame

# %%
metaMap.metabolitesMapping
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7f887b475780> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
#   CAS: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b475940> [RTYPES.STRSXP]
# R classes: ('character',)
# ['18523-69..., '75-05-8', '65734-38..., '520-45-6', ..., '77172-80..., '77172-80..., '133-89-1', NA_character_]
#   DTXSID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b47ea40> [RTYPES.STRSXP]
# R classes: ('character',)
# ['DTXSID20..., 'DTXSID70..., 'DTXSID60..., 'DTXSID60..., ..., NA_character_, NA_character_, 'DTXSID00..., NA_character_]
#   DTXCID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b475700> [RTYPES.STRSXP]
# R classes: ('character',)
# ['DTXCID808', 'DTXCID909', 'DTXCID50..., 'DTXCID90..., ..., NA_character_, NA_character_, 'DTXCID80..., NA_character_]
#   SID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f88f93d76c0> [RTYPES.STRSXP]
# R classes: ('character',)
# ['315671030', '315671031', '315671033', '315671035', ..., NA_character_, NA_character_, NA_character_, NA_character_]
# ...
#   KEGG: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887f4ccd40> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '38472', NA_character_, '137426', ..., '166759', '167579', '167608', '64645']
#   ChEBI: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887f4cce80> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, 'HMDB0061..., NA_character_, NA_character_, ..., 'HMDB0010..., 'HMDB0010..., 'HMDB0000..., NA_character_]
#   HMDB: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887f4cccc0> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, NA_character_, NA_character_, NA_character_, ..., NA_character_, NA_character_, 'DB01861', NA_character_]
#   Drugbank: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887f4ec380> [RTYPES.STRSXP]
# R classes: ('character',)
# ['Acetone[..., 'Acetonit..., "N'-Acety..., 'Dehydroa..., ..., 'Cholesta..., 'Cholesta..., 'Uridine ..., NA_character_]

# %%
list(metaMap.metabolitesMapping.colnames)
# Out:
# ['CAS',
#  'DTXSID',
#  'DTXCID',
#  'SID',
#  'CID',
#  'KEGG',
#  'ChEBI',
#  'HMDB',
#  'Drugbank',
#  'Name']

# %%
type(metaMap.metabolitesMapping)
# Out:
# rpy2.robjects.vectors.DataFrame

# %%
metaMap.metabolitesMapping
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7f88e87797c0> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
#   CAS: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f88d8301340> [RTYPES.STRSXP]
# R classes: ('character',)
# ['18523-69..., '75-05-8', '65734-38..., '520-45-6', ..., '77172-80..., '77172-80..., '133-89-1', NA_character_]
#   DTXSID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f88d8312180> [RTYPES.STRSXP]
# R classes: ('character',)
# ['DTXSID20..., 'DTXSID70..., 'DTXSID60..., 'DTXSID60..., ..., NA_character_, NA_character_, 'DTXSID00..., NA_character_]
#   DTXCID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f88f93d7b40> [RTYPES.STRSXP]
# R classes: ('character',)
# ['DTXCID808', 'DTXCID909', 'DTXCID50..., 'DTXCID90..., ..., NA_character_, NA_character_, 'DTXCID80..., NA_character_]
#   SID: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b472b80> [RTYPES.STRSXP]
# R classes: ('character',)
# ['315671030', '315671031', '315671033', '315671035', ..., NA_character_, NA_character_, NA_character_, NA_character_]
# ...
#   KEGG: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b472800> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '38472', NA_character_, '137426', ..., '166759', '167579', '167608', '64645']
#   ChEBI: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b475800> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, 'HMDB0061..., NA_character_, NA_character_, ..., 'HMDB0010..., 'HMDB0010..., 'HMDB0000..., NA_character_]
#   HMDB: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b475900> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, NA_character_, NA_character_, NA_character_, ..., NA_character_, NA_character_, 'DB01861', NA_character_]
#   Drugbank: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7f887b4752c0> [RTYPES.STRSXP]
# R classes: ('character',)
# ['Acetone[..., 'Acetonit..., "N'-Acety..., 'Dehydroa..., ..., 'Cholesta..., 'Cholesta..., 'Uridine ..., NA_character_]

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
  pd_from_r_df = ro.conversion.rpy2py(metaMap.metabolitesMapping)

pd_from_r_df
# Out:
#                 CAS          DTXSID         DTXCID        SID       CID  \
# 1        18523-69-8   DTXSID2020008      DTXCID808  315671030   4415524
# 2           75-05-8   DTXSID7020009      DTXCID909  315671031      6342
# 3        65734-38-5   DTXSID6020012     DTXCID5012  315671033    107949
# 4          520-45-6   DTXSID6020014     DTXCID9014  315671035    122903
# 5          114-83-0   DTXSID1020015     DTXCID1015  315671036      8247
# ...             ...             ...            ...        ...       ...
# 1012263  20562-03-2            None           None       None    442971
# 1012264  77172-80-6            None           None       None  42622727
# 1012265  77172-80-6            None           None       None  42622727
# 1012266    133-89-1  DTXSID00157902  DTXCID8080393       None      8629
# 1012267        None            None           None       None      None
#
#            KEGG   ChEBI         HMDB Drugbank  \
# 1          None    None         None     None
# 2          None   38472  HMDB0061869     None
# 3          None    None         None     None
# 4          None  137426         None     None
# 5          None    None         None     None
# ...         ...     ...          ...      ...
# 1012263  C10796   10219  HMDB0240575     None
# 1012264  C03033  166759  HMDB0010355     None
# 1012265  C03033  167579  HMDB0010355     None
# 1012266  C00029  167608  HMDB0000286  DB01861
# 1012267  C16515   64645         None     None
#
#                                                       Name
# 1        Acetone[4-(5-nitro-2-furyl)-2-thiazolyl] hydra...
# 2                                             Acetonitrile
# 3              N'-Acetyl-4-(hydroxymethyl) phenylhydrazine
# 4                                       Dehydroacetic acid
# 5                               1-Acetyl-2-phenylhydrazine
# ...                                                    ...
# 1012263                                        Α-chaconine
# 1012264          Cholestane-3,7,12,25-tetrol-3-glucuronide
# 1012265          Cholestane-3,7,12,25-tetrol-3-glucuronide
# 1012266                        Uridine diphosphate glucose
# 1012267                                               None
#
# [1012267 rows x 10 columns]

# %%
pd_from_r_df.head()
# Out:
#           CAS         DTXSID      DTXCID        SID      CID  KEGG   ChEBI  \
# 1  18523-69-8  DTXSID2020008   DTXCID808  315671030  4415524  None    None
# 2     75-05-8  DTXSID7020009   DTXCID909  315671031     6342  None   38472
# 3  65734-38-5  DTXSID6020012  DTXCID5012  315671033   107949  None    None
# 4    520-45-6  DTXSID6020014  DTXCID9014  315671035   122903  None  137426
# 5    114-83-0  DTXSID1020015  DTXCID1015  315671036     8247  None    None
#
#           HMDB Drugbank                                               Name
# 1         None     None  Acetone[4-(5-nitro-2-furyl)-2-thiazolyl] hydra...
# 2  HMDB0061869     None                                       Acetonitrile
# 3         None     None        N'-Acetyl-4-(hydroxymethyl) phenylhydrazine
# 4         None     None                                 Dehydroacetic acid
# 5         None     None                         1-Acetyl-2-phenylhydrazine

# %%
pd_from_r_df['HMDB']
# Out:
# 1                 None
# 2          HMDB0061869
# 3                 None
# 4                 None
# 5                 None
#               ...
# 1012263    HMDB0240575
# 1012264    HMDB0010355
# 1012265    HMDB0010355
# 1012266    HMDB0000286
# 1012267           None
# Name: HMDB, Length: 1012267, dtype: object

# %%
pd_from_r_df.columns
# Out:
# Index(['CAS', 'DTXSID', 'DTXCID', 'SID', 'CID', 'KEGG', 'ChEBI', 'HMDB',
#        'Drugbank', 'Name'],
#       dtype='object')
